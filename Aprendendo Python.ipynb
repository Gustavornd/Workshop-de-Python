# %%
# A declaração de variáveis não precisa de tipos
var1 = 10
var2 = 56.4
var3 = "Olá mundo"

print(var1, var2, var3)

# %%
# Atrubuindo valor para uma variável
    # O comando input sempre retorna uma string
nome = input("Escreva seu nome: ")
idade = int(input("Escreva sua idade: "))
altura = float(input("Escreva sua altura: "))

print("NOME: ",nome)
print("IDADE: ", idade)
print("ALTURA: ", altura)
# Out:
# Escreva seu nome: Gustavo Rafael Nunes Durães
# Escreva sua idade: 22
# Escreva sua altura: 1.87
# NOME:  Gustavo Rafael Nunes Durães
# IDADE:  22
# ALTURA:  1.87

# %%
# Para concatenar String usamos o operador +

print("Apostila"+" de "+"Python")

a = 'Programação'
b = " em Python"
c = a+b
print(c)
# Out:
# Apostila de Python
# Programação em Python

# %% [markdown]
# ![imagem_2022-03-14_203001.png](attachment:imagem_2022-03-14_203001.png)

# %%
# 1-
A = "Um elefante incomoda muita gente"
print(A[3:20]) #printa apenas a parte "elefante incomoda"


# 2-
a = input("Insira uma frase: ")
a = a.upper()
a = a.strip()
print(a)
# Out:
# elefante incomoda
# Insira uma frase: Gustavo é feio demais
# GUSTAVO É FEIO DEMAIS

# %% [markdown]
# ![imagem_2022-03-14_202505.png](attachment:imagem_2022-03-14_202505.png)

# %%
# 1-
x = int(input("Insira um valor: "))
y = int(input("Insira um valor: "))

z = ((x**2)+(y**2))/((x-y)**2)
print(z)

# 2-
salario = float(input("Insira o salário: "))
salario = salario + (salario*0.35)
print(salario)
# Out:
# Insira um valor: 5
# Insira um valor: 6
# 61.0
# Insira o salário: 1000.00
# 1350.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1-
L = [5, 7, 2, 9, 4, 1, 3]
print("a: ", len(L))
print("b: ", max(L))
print("c: ", min(L))
print("d: ", sum(L))
L.sort()
print("e: ", L)
L.reverse()
print("f: ", L)

# 2- ????? Não sei como fazer uma lista com multiplos de 3 sem usar for
multiplos = list(range(1,50,3))
print(multiplos)
# Out:
# a:  7
# b:  9
# c:  1
# d:  31
# e:  [1, 2, 3, 4, 5, 7, 9]
# f:  [9, 7, 5, 4, 3, 2, 1]
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49]
